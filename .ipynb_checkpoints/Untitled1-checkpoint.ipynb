# %%
import numpy as np

def list_to_int(str_list):
    return [int(x) for x in str_list]

def read_input(path):
    with open(path) as f:
        return(f.read().split("\n")[:-1])

# %%
with open('./data/day_6/input.txt') as f:
    fishs = list_to_int(f.read().splitlines()[0].split(","))
    
def def_value():
    return 0

new_dict = defaultdict(def_value)

for item in fish:
    new_dict[item] += 1
    
def get_fish_count(iterations):
    for i in range(iterations):
        new_fish = new_dict[0]

        for i in range(0,8):
            new_dict[i] = new_dict[i+1]

        new_dict[6] = new_dict[6]+ new_fish
        new_dict[8] = new_fish
    return sum(new_dict.values())
# Out:
# [2,
#  1,
#  1,
#  4,
#  4,
#  1,
#  3,
#  4,
#  2,
#  4,
#  2,
#  1,
#  1,
#  4,
#  3,
#  5,
#  1,
#  1,
#  5,
#  1,
#  1,
#  5,
#  4,
#  5,
#  4,
#  1,
#  5,
#  1,
#  3,
#  1,
#  4,
#  2,
#  3,
#  2,
#  1,
#  2,
#  5,
#  5,
#  2,
#  3,
#  1,
#  2,
#  3,
#  3,
#  1,
#  4,
#  3,
#  1,
#  1,
#  1,
#  1,
#  5,
#  2,
#  1,
#  1,
#  1,
#  5,
#  3,
#  3,
#  2,
#  1,
#  4,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  5,
#  5,
#  1,
#  4,
#  4,
#  4,
#  4,
#  5,
#  1,
#  5,
#  1,
#  1,
#  5,
#  5,
#  2,
#  2,
#  5,
#  4,
#  1,
#  5,
#  4,
#  1,
#  4,
#  1,
#  1,
#  1,
#  1,
#  5,
#  3,
#  2,
#  4,
#  1,
#  1,
#  1,
#  4,
#  4,
#  1,
#  2,
#  1,
#  1,
#  5,
#  2,
#  1,
#  1,
#  1,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  1,
#  1,
#  5,
#  1,
#  5,
#  2,
#  1,
#  4,
#  1,
#  2,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  1,
#  5,
#  5,
#  2,
#  1,
#  1,
#  1,
#  4,
#  4,
#  1,
#  4,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  5,
#  4,
#  1,
#  5,
#  1,
#  4,
#  5,
#  5,
#  1,
# ...

# %%
with open('./data/day_6/input.txt') as f:
    data = f.read().splitlines()
from collections import defaultdict

fish = list_to_int(data[0].split(","))

def def_value():
    return 0

new_dict = defaultdict(def_value)

for item in fish:
    new_dict[item] += 1

len_list = []
for i in range(256):
    new_fish = new_dict[0]
    
    for i in range(0,8):
        new_dict[i] = new_dict[i+1]
    
    new_dict[6] = new_dict[6]+ new_fish
    new_dict[8] = new_fish

# %%
with open('./data/day_6/input.txt') as f:
    data = f.read().splitlines()
from collections import defaultdict

fish = list_to_int(data[0].split(","))

def def_value():
    return 0

new_dict = defaultdict(def_value)

for item in fish:
    new_dict[item] += 1

# %%
sum(new_dict.values())
# Out:
# 1632779838045
